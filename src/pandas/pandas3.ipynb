# %% [markdown]
# <h1>cleaning and pre-processing</h1><br>

# %%
import pandas as pd

# %%
data  = pd.read_csv("data-files/kpis_1998_2003.csv")
# Out:
# /tmp/ipykernel_174546/2932136156.py:1: DtypeWarning: Columns (1,2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data  = pd.read_csv("data-files/kpis_1998_2003.csv")

# %%
data.isnull().sum()
# Out:
# kpi                      0
# period                   0
# municipality_id          0
# municipality_name        0
# value                47257
# kpi_desc                 0
# dtype: int64

# %%
data.head()
# Out:
#       kpi period municipality_id municipality_name      value  \
# 0  N00002   1998             114    Upplands Väsby  61.000001
# 1  N00002   1998             115        Vallentuna  58.999997
# 2  N00002   1998             117         Österåker  56.999999
# 3  N00002   1998             120            Värmdö  52.999997
# 4  N00002   1998             123          Järfälla       56.0
#
#                                             kpi_desc
# 0  Personalkostnader kommunen totalt, dividerat m...
# 1  Personalkostnader kommunen totalt, dividerat m...
# 2  Personalkostnader kommunen totalt, dividerat m...
# 3  Personalkostnader kommunen totalt, dividerat m...
# 4  Personalkostnader kommunen totalt, dividerat m...

# %%
#data = data.dropna().copy()
#data
#we will lose 47k+ columns due to all of it

# %%
data["value"] = pd.to_numeric(data["value"], errors="coerce")

# %%
#data.fillna(0)
data["value"] = data["value"].fillna(data["value"].mean()).copy()
data.isnull().sum()
# Out:
# kpi                  0
# period               0
# municipality_id      0
# municipality_name    0
# value                0
# kpi_desc             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(4)

# %%
data = data.drop_duplicates().copy()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#use .astype() or pd.type_function() to convert types in pandas data frames
