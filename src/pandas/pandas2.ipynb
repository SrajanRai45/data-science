# %% [markdown]
# <h1>DATA SELECTION AND FILTERING</h1>

# %%
import pandas as pd

# %%
df = pd.read_csv("../data-files/co2_emissions.csv")
print(df.head())
# Out:
#    year  month  decimal_date  co2_ppm     data_source    measurement_type
# 0  1958      3     1958.2027   315.71  NOAA_Mauna_Loa  atmospheric_direct
# 1  1958      4     1958.2877   317.45  NOAA_Mauna_Loa  atmospheric_direct
# 2  1958      5     1958.3699   317.51  NOAA_Mauna_Loa  atmospheric_direct
# 3  1958      6     1958.4548   317.27  NOAA_Mauna_Loa  atmospheric_direct
# 4  1958      7     1958.5370   315.87  NOAA_Mauna_Loa  atmospheric_direct

# %% [markdown]
# **<h4>ACCESS</h4>**

# %%
df["year"]
# Out:
# 0     1958
# 1     1958
# 2     1958
# 3     1958
# 4     1958
#       ...
# 95    1966
# 96    1966
# 97    1966
# 98    1966
# 99    1966
# Name: year, Length: 100, dtype: int64

# %%
df[["year" , "month"]]
# Out:
#     year  month
# 0   1958      3
# 1   1958      4
# 2   1958      5
# 3   1958      6
# 4   1958      7
# ..   ...    ...
# 95  1966      2
# 96  1966      3
# 97  1966      4
# 98  1966      5
# 99  1966      6
#
# [100 rows x 2 columns]
