# %% [markdown]
# <h1>DATA FRAMES</h1>

# %%
import pandas as pd
import random
import numpy as np

# %%
data = "abcdefghijklmnopqrstuvwxyz"

# %%
data[random.randrange(0,26)]
# Out:
# 'h'

# %%
df = [[f" {data[random.randrange(0,26)]} {data[random.randrange(0,26)]} {data[random.randrange(0,26)]}", i ] for i in range(100, 10000 , 100) ]

# %%
df2 = pd.DataFrame(df , columns = ["something's","fishy"])

# %%
df2
# Out:
#    something's  fishy
# 0        d p t    100
# 1        f c g    200
# 2        k l e    300
# 3        s n m    400
# 4        h z w    500
# ..         ...    ...
# 94       l g u   9500
# 95       z q e   9600
# 96       t d m   9700
# 97       f g e   9800
# 98       p n w   9900
#
# [99 rows x 2 columns]

# %%
df2.head()
# Out:
#   something's  fishy
# 0       d p t    100
# 1       f c g    200
# 2       k l e    300
# 3       s n m    400
# 4       h z w    500

# %%
df2.tail()
# Out:
#    something's  fishy
# 94       l g u   9500
# 95       z q e   9600
# 96       t d m   9700
# 97       f g e   9800
# 98       p n w   9900

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   something's  99 non-null     object
#  1   fishy        99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
df2.describe()
# Out:
#              fishy
# count    99.000000
# mean   5000.000000
# std    2872.281323
# min     100.000000
# 25%    2550.000000
# 50%    5000.000000
# 75%    7450.000000
# max    9900.000000

# %%
print(f"{df2.shape} is shape , the next one is columns {df2.columns}")
# Out:
# (99, 2) is shape , the next one is columns Index(['something's', 'fishy'], dtype='object')

# %%
a = np.array([[1,2],[2,1]])
adf = pd.DataFrame(a,columns=["A","B"])
adf
# Out:
#    A  B
# 0  1  2
# 1  2  1
